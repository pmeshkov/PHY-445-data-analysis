# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rabi = np.array([4.7652526755750095,3.8750051180312397,3.2061395996122957,2.56423329346441,1.935770576007635,1.5242542974377047])
power = np.array([-10,-12,-14,-16,-18,-20])

# %%
plt.figure(figsize=(10,5))
plt.scatter(power, rabi)
